# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('covid19_italy_region.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#        SNo                 Date Country  RegionCode      RegionName  \
# 0        0  2020-02-24T18:00:00     ITA          13         Abruzzo
# 1        1  2020-02-24T18:00:00     ITA          17      Basilicata
# 2        2  2020-02-24T18:00:00     ITA          18        Calabria
# 3        3  2020-02-24T18:00:00     ITA          15        Campania
# 4        4  2020-02-24T18:00:00     ITA           8  Emilia-Romagna
# ...    ...                  ...     ...         ...             ...
# 6022  6022  2020-12-06T17:00:00     ITA          19         Sicilia
# 6023  6023  2020-12-06T17:00:00     ITA           9         Toscana
# 6024  6024  2020-12-06T17:00:00     ITA          10          Umbria
# 6025  6025  2020-12-06T17:00:00     ITA           2   Valle d'Aosta
# 6026  6026  2020-12-06T17:00:00     ITA           5          Veneto
#
#        Latitude  Longitude  HospitalizedPatients  IntensiveCarePatients  \
# 0     42.351222  13.398438                     0                      0
# ...

# %%
df.head()
# Out:
#    SNo                 Date Country  RegionCode      RegionName   Latitude  \
# 0    0  2020-02-24T18:00:00     ITA          13         Abruzzo  42.351222
# 1    1  2020-02-24T18:00:00     ITA          17      Basilicata  40.639471
# 2    2  2020-02-24T18:00:00     ITA          18        Calabria  38.905976
# 3    3  2020-02-24T18:00:00     ITA          15        Campania  40.839566
# 4    4  2020-02-24T18:00:00     ITA           8  Emilia-Romagna  44.494367
#
#    Longitude  HospitalizedPatients  IntensiveCarePatients  \
# 0  13.398438                     0                      0
# 1  15.805148                     0                      0
# 2  16.594402                     0                      0
# 3  14.250850                     0                      0
# 4  11.341721                    10                      2
#
#    TotalHospitalizedPatients  HomeConfinement  CurrentPositiveCases  \
# 0                          0                0                     0
# ...

# %%
df.info()   #test perfomed has some Nan values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6027 entries, 0 to 6026
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   SNo                        6027 non-null   int64
#  1   Date                       6027 non-null   object
#  2   Country                    6027 non-null   object
#  3   RegionCode                 6027 non-null   int64
#  4   RegionName                 6027 non-null   object
#  5   Latitude                   6027 non-null   float64
#  6   Longitude                  6027 non-null   float64
#  7   HospitalizedPatients       6027 non-null   int64
#  8   IntensiveCarePatients      6027 non-null   int64
#  9   TotalHospitalizedPatients  6027 non-null   int64
#  10  HomeConfinement            6027 non-null   int64
#  11  CurrentPositiveCases       6027 non-null   int64
#  12  NewPositiveCases           6027 non-null   int64
# ...

# %%
df.describe()
# Out:
#                SNo   RegionCode     Latitude    Longitude  \
# count  6027.000000  6027.000000  6027.000000  6027.000000
# mean   3013.000000    11.857143    43.046293    12.225955
# std    1739.989368     6.274319     2.488987     2.659168
# min       0.000000     1.000000    38.115697     7.320149
# 25%    1506.500000     7.000000    41.125596    11.121231
# 50%    3013.000000    12.000000    43.616760    12.388247
# 75%    4519.500000    17.000000    45.434905    13.768136
# max    6026.000000    22.000000    46.499335    16.867367
#
#        HospitalizedPatients  IntensiveCarePatients  TotalHospitalizedPatients  \
# count           6027.000000            6027.000000                6027.000000
# mean             509.093579              55.892318                 564.985897
# std             1272.731157             134.957979                1403.362341
# min                0.000000               0.000000                   0.000000
# ...

# %%
df.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'Latitude',
#        'Longitude', 'HospitalizedPatients', 'IntensiveCarePatients',
#        'TotalHospitalizedPatients', 'HomeConfinement', 'CurrentPositiveCases',
#        'NewPositiveCases', 'Recovered', 'Deaths', 'TotalPositiveCases',
#        'TestsPerformed'],
#       dtype='object')

# %%
df.shape
# Out:
# (6027, 17)

# %%
df['RegionCode']
# Out:
# 0       13
# 1       17
# 2       18
# 3       15
# 4        8
#         ..
# 6022    19
# 6023     9
# 6024    10
# 6025     2
# 6026     5
# Name: RegionCode, Length: 6027, dtype: int64

# %%
type(df['RegionCode'])    #It is a series dataTyoe
# Out:
# pandas.core.series.Series

# %%
df['RegionCode'][240]
# Out:
# 11

# %%
df2 = df['RegionCode']

# %%
df2               # df2 and df both point to the same dataFrame so changes in one means changes in both
# Out:
# 0       13
# 1       17
# 2       18
# 3       15
# 4        8
#         ..
# 6022    19
# 6023     9
# 6024    10
# 6025     2
# 6026     5
# Name: RegionCode, Length: 6027, dtype: int64

# %%
# Instead use this

# %%
df_copy = df.copy()

# %%
df_copy
# Out:
#        SNo                 Date Country  RegionCode      RegionName  \
# 0        0  2020-02-24T18:00:00     ITA          13         Abruzzo
# 1        1  2020-02-24T18:00:00     ITA          17      Basilicata
# 2        2  2020-02-24T18:00:00     ITA          18        Calabria
# 3        3  2020-02-24T18:00:00     ITA          15        Campania
# 4        4  2020-02-24T18:00:00     ITA           8  Emilia-Romagna
# ...    ...                  ...     ...         ...             ...
# 6022  6022  2020-12-06T17:00:00     ITA          19         Sicilia
# 6023  6023  2020-12-06T17:00:00     ITA           9         Toscana
# 6024  6024  2020-12-06T17:00:00     ITA          10          Umbria
# 6025  6025  2020-12-06T17:00:00     ITA           2   Valle d'Aosta
# 6026  6026  2020-12-06T17:00:00     ITA           5          Veneto
#
#        Latitude  Longitude  HospitalizedPatients  IntensiveCarePatients  \
# 0     42.351222  13.398438                     0                      0
# ...

# %%
# To get particluar row

df.loc[400]
# Out:
# SNo                                          400
# Date                         2020-03-14T17:00:00
# Country                                      ITA
# RegionCode                                    17
# RegionName                            Basilicata
# Latitude                               40.639471
# Longitude                              15.805148
# HospitalizedPatients                           0
# IntensiveCarePatients                          2
# TotalHospitalizedPatients                      2
# HomeConfinement                                8
# CurrentPositiveCases                          10
# NewPositiveCases                               0
# Recovered                                      0
# Deaths                                         0
# TotalPositiveCases                            10
# TestsPerformed                               NaN
# Name: 400, dtype: object

# %%
df.tail()
# Out:
#        SNo                 Date Country  RegionCode     RegionName   Latitude  \
# 6022  6022  2020-12-06T17:00:00     ITA          19        Sicilia  38.115697
# 6023  6023  2020-12-06T17:00:00     ITA           9        Toscana  43.769231
# 6024  6024  2020-12-06T17:00:00     ITA          10         Umbria  43.106758
# 6025  6025  2020-12-06T17:00:00     ITA           2  Valle d'Aosta  45.737503
# 6026  6026  2020-12-06T17:00:00     ITA           5         Veneto  45.434905
#
#       Longitude  HospitalizedPatients  IntensiveCarePatients  \
# 6022  13.362357                  1367                    213
# 6023  11.255889                  1360                    252
# 6024  12.388247                   332                     60
# 6025   7.320149                   102                      8
# 6026  12.338452                  2508                    308
#
#       TotalHospitalizedPatients  HomeConfinement  CurrentPositiveCases  \
# ...

# %%
df.isnull()
# Out:
#         SNo   Date  Country  RegionCode  RegionName  Latitude  Longitude  \
# 0     False  False    False       False       False     False      False
# 1     False  False    False       False       False     False      False
# 2     False  False    False       False       False     False      False
# 3     False  False    False       False       False     False      False
# 4     False  False    False       False       False     False      False
# ...     ...    ...      ...         ...         ...       ...        ...
# 6022  False  False    False       False       False     False      False
# 6023  False  False    False       False       False     False      False
# 6024  False  False    False       False       False     False      False
# 6025  False  False    False       False       False     False      False
# 6026  False  False    False       False       False     False      False
#
#       HospitalizedPatients  IntensiveCarePatients  TotalHospitalizedPatients  \
# ...

# %%
df.isnull().sum()
# Out:
# SNo                             0
# Date                            0
# Country                         0
# RegionCode                      0
# RegionName                      0
# Latitude                        0
# Longitude                       0
# HospitalizedPatients            0
# IntensiveCarePatients           0
# TotalHospitalizedPatients       0
# HomeConfinement                 0
# CurrentPositiveCases            0
# NewPositiveCases                0
# Recovered                       0
# Deaths                          0
# TotalPositiveCases              0
# TestsPerformed               1155
# dtype: int64

# %%
df.TestsPerformed.first_valid_index()
# Out:
# 1155

# %%
df.loc[1155]
# Out:
# SNo                                         1155
# Date                         2020-04-19T17:00:00
# Country                                      ITA
# RegionCode                                    13
# RegionName                               Abruzzo
# Latitude                               42.351222
# Longitude                              13.398438
# HospitalizedPatients                         317
# IntensiveCarePatients                         40
# TotalHospitalizedPatients                    357
# HomeConfinement                             1630
# CurrentPositiveCases                        1987
# NewPositiveCases                              34
# Recovered                                    276
# Deaths                                       258
# TotalPositiveCases                          2521
# TestsPerformed                           22424.0
# Name: 1155, dtype: object

# %%
df.loc[1154]
# Out:
# SNo                                         1154
# Date                         2020-04-18T17:00:00
# Country                                      ITA
# RegionCode                                     5
# RegionName                                Veneto
# Latitude                               45.434905
# Longitude                              12.338452
# HospitalizedPatients                        1287
# IntensiveCarePatients                        190
# TotalHospitalizedPatients                   1477
# HomeConfinement                             8967
# CurrentPositiveCases                       10444
# NewPositiveCases                             318
# Recovered                                   4189
# Deaths                                      1059
# TotalPositiveCases                         15692
# TestsPerformed                               NaN
# Name: 1154, dtype: object

# %%
df.Deaths.sum()
# Out:
# 8886032

# %%
df.Recovered.sum()
# Out:
# 56279239

# %%
death_rate = df.Deaths.sum()/df.TotalPositiveCases.sum()

# %%
print("Death Rate {:.2f} %".format(death_rate))
# Out:
# Death Rate 0.09 %

# %%
high_cases = df.NewPositiveCases > 1000

# %%
high_cases
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6022     True
# 6023    False
# 6024    False
# 6025    False
# 6026     True
# Name: NewPositiveCases, Length: 6027, dtype: bool

# %%
df[high_cases]    # You can pass a variable as a index to find desired rows
# Out:
#        SNo                 Date Country  RegionCode RegionName   Latitude  \
# 302    302  2020-03-09T18:00:00     ITA           3  Lombardia  45.466794
# 344    344  2020-03-11T17:00:00     ITA           3  Lombardia  45.466794
# 365    365  2020-03-12T17:00:00     ITA           3  Lombardia  45.466794
# 386    386  2020-03-13T17:00:00     ITA           3  Lombardia  45.466794
# 407    407  2020-03-14T17:00:00     ITA           3  Lombardia  45.466794
# ...    ...                  ...     ...         ...        ...        ...
# 6014  6014  2020-12-06T17:00:00     ITA           3  Lombardia  45.466794
# 6019  6019  2020-12-06T17:00:00     ITA           1   Piemonte  45.073274
# 6020  6020  2020-12-06T17:00:00     ITA          16     Puglia  41.125596
# 6022  6022  2020-12-06T17:00:00     ITA          19    Sicilia  38.115697
# 6026  6026  2020-12-06T17:00:00     ITA           5     Veneto  45.434905
#
#       Longitude  HospitalizedPatients  IntensiveCarePatients  \
# ...

# %%
# Adding a new columm

df['Positive_rate'] = df['NewPositiveCases']/df['TotalPositiveCases']

# %%
df
# Out:
#        SNo                 Date Country  RegionCode      RegionName  \
# 0        0  2020-02-24T18:00:00     ITA          13         Abruzzo
# 1        1  2020-02-24T18:00:00     ITA          17      Basilicata
# 2        2  2020-02-24T18:00:00     ITA          18        Calabria
# 3        3  2020-02-24T18:00:00     ITA          15        Campania
# 4        4  2020-02-24T18:00:00     ITA           8  Emilia-Romagna
# ...    ...                  ...     ...         ...             ...
# 6022  6022  2020-12-06T17:00:00     ITA          19         Sicilia
# 6023  6023  2020-12-06T17:00:00     ITA           9         Toscana
# 6024  6024  2020-12-06T17:00:00     ITA          10          Umbria
# 6025  6025  2020-12-06T17:00:00     ITA           2   Valle d'Aosta
# 6026  6026  2020-12-06T17:00:00     ITA           5          Veneto
#
#        Latitude  Longitude  HospitalizedPatients  IntensiveCarePatients  \
# 0     42.351222  13.398438                     0                      0
# ...

# %%
# Drop a column

df.drop(columns=['Positive_rate'],inplace=True)

# %%
df
# Out:
#        SNo                 Date Country  RegionCode      RegionName  \
# 0        0  2020-02-24T18:00:00     ITA          13         Abruzzo
# 1        1  2020-02-24T18:00:00     ITA          17      Basilicata
# 2        2  2020-02-24T18:00:00     ITA          18        Calabria
# 3        3  2020-02-24T18:00:00     ITA          15        Campania
# 4        4  2020-02-24T18:00:00     ITA           8  Emilia-Romagna
# ...    ...                  ...     ...         ...             ...
# 6022  6022  2020-12-06T17:00:00     ITA          19         Sicilia
# 6023  6023  2020-12-06T17:00:00     ITA           9         Toscana
# 6024  6024  2020-12-06T17:00:00     ITA          10          Umbria
# 6025  6025  2020-12-06T17:00:00     ITA           2   Valle d'Aosta
# 6026  6026  2020-12-06T17:00:00     ITA           5          Veneto
#
#        Latitude  Longitude  HospitalizedPatients  IntensiveCarePatients  \
# 0     42.351222  13.398438                     0                      0
# ...

# %%
df.sort_values('Deaths').head(10)
# Out:
#      SNo                 Date Country  RegionCode     RegionName   Latitude  \
# 0      0  2020-02-24T18:00:00     ITA          13        Abruzzo  42.351222
# 181  181  2020-03-03T18:00:00     ITA           1       Piemonte  45.073274
# 182  182  2020-03-03T18:00:00     ITA          16         Puglia  41.125596
# 183  183  2020-03-03T18:00:00     ITA          20       Sardegna  39.215312
# 184  184  2020-03-03T18:00:00     ITA          19        Sicilia  38.115697
# 185  185  2020-03-03T18:00:00     ITA           9        Toscana  43.769231
# 186  186  2020-03-03T18:00:00     ITA          10         Umbria  43.106758
# 187  187  2020-03-03T18:00:00     ITA           2  Valle d'Aosta  45.737503
# 375  375  2020-03-12T17:00:00     ITA          10         Umbria  43.106758
# 189  189  2020-03-04T17:00:00     ITA          13        Abruzzo  42.351222
#
#      Longitude  HospitalizedPatients  IntensiveCarePatients  \
# 0    13.398438                     0                      0
# ...

# %%
df['Date'] = pd.to_datetime(df.Date)

# %%
df['Country'] = 'Italy'

# %%
df
# Out:
#        SNo                Date Country  RegionCode      RegionName   Latitude  \
# 0        0 2020-02-24 18:00:00   Italy          13         Abruzzo  42.351222
# 1        1 2020-02-24 18:00:00   Italy          17      Basilicata  40.639471
# 2        2 2020-02-24 18:00:00   Italy          18        Calabria  38.905976
# 3        3 2020-02-24 18:00:00   Italy          15        Campania  40.839566
# 4        4 2020-02-24 18:00:00   Italy           8  Emilia-Romagna  44.494367
# ...    ...                 ...     ...         ...             ...        ...
# 6022  6022 2020-12-06 17:00:00   Italy          19         Sicilia  38.115697
# 6023  6023 2020-12-06 17:00:00   Italy           9         Toscana  43.769231
# 6024  6024 2020-12-06 17:00:00   Italy          10          Umbria  43.106758
# 6025  6025 2020-12-06 17:00:00   Italy           2   Valle d'Aosta  45.737503
# 6026  6026 2020-12-06 17:00:00   Italy           5          Veneto  45.434905
#
# ...

# %%
# Merge two dataframes
# MErging happens only when there is a common column in the two dataframes

locations_df = pd.read_csv('')
merged_df = df.merge(locations_df, on='location')   ## This will create new dataframe 

# locations_df will merge with df on the basis of location column which is common columns.


# It will return a new dataframe 
# In locations_df there is location column which has many locations for example Italy, India etc 

# It will look into df for the same entries and merge the rows in the df dataframe
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [49], in <cell line: 4>()
#       1 # Merge two dataframes
#       2 # MErging happens only when there is a common column in the two dataframes
# ----> 4 locations_df = pd.read_csv('')
#       5 merged_df = df.merge(locations_df, on='location')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
result_df = mergeed_df = [['Date', your requied columns]]

# %%
result_df.to_csv('results.csv',index=False)     # To save in results.csv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [50], in <cell line: 1>()
# ----> 1 result_df.to_csv('results.csv',index=False)
#
# NameError: name 'result_df' is not defined

# %%
# Basic plotting with Pandas

# %%
df
# Out:
#        SNo                Date Country  RegionCode      RegionName   Latitude  \
# 0        0 2020-02-24 18:00:00   Italy          13         Abruzzo  42.351222
# 1        1 2020-02-24 18:00:00   Italy          17      Basilicata  40.639471
# 2        2 2020-02-24 18:00:00   Italy          18        Calabria  38.905976
# 3        3 2020-02-24 18:00:00   Italy          15        Campania  40.839566
# 4        4 2020-02-24 18:00:00   Italy           8  Emilia-Romagna  44.494367
# ...    ...                 ...     ...         ...             ...        ...
# 6022  6022 2020-12-06 17:00:00   Italy          19         Sicilia  38.115697
# 6023  6023 2020-12-06 17:00:00   Italy           9         Toscana  43.769231
# 6024  6024 2020-12-06 17:00:00   Italy          10          Umbria  43.106758
# 6025  6025 2020-12-06 17:00:00   Italy           2   Valle d'Aosta  45.737503
# 6026  6026 2020-12-06 17:00:00   Italy           5          Veneto  45.434905
#
# ...

# %%
df['Deaths'].plot()
# Out:
# <Axes: >

# %%
df.Recovered.plot()
# Out:
# <Axes: >

# %%
df.set_index('Date',inplace=True)    # How to change index
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [70], in <cell line: 1>()
# ----> 1 df.set_index('Date',inplace=True)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:5500, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5497                 missing.append(col)
#    5499 if missing:
# -> 5500     raise KeyError(f"None of {missing} are in the columns")
# ...

# %%
df.NewPositiveCases.plot()
df.Deaths.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
death_rate = df['Deaths']/df['TotalPositiveCases']

# %%
death_rate.plot(title='Death Rate');

# %%
df
# Out:
#                       SNo Country  RegionCode      RegionName   Latitude  \
# Date
# 2020-02-24 18:00:00     0   Italy          13         Abruzzo  42.351222
# 2020-02-24 18:00:00     1   Italy          17      Basilicata  40.639471
# 2020-02-24 18:00:00     2   Italy          18        Calabria  38.905976
# 2020-02-24 18:00:00     3   Italy          15        Campania  40.839566
# 2020-02-24 18:00:00     4   Italy           8  Emilia-Romagna  44.494367
# ...                   ...     ...         ...             ...        ...
# 2020-12-06 17:00:00  6022   Italy          19         Sicilia  38.115697
# 2020-12-06 17:00:00  6023   Italy           9         Toscana  43.769231
# 2020-12-06 17:00:00  6024   Italy          10          Umbria  43.106758
# 2020-12-06 17:00:00  6025   Italy           2   Valle d'Aosta  45.737503
# 2020-12-06 17:00:00  6026   Italy           5          Veneto  45.434905
#
#                      Longitude  HospitalizedPatients  IntensiveCarePatients  \
# Date
# ...

# %%
positive_rate = df['NewPositiveCases']/df['TotalPositiveCases']

# %%
positive_rate.plot(title='Positive Rate')
# Out:
# <Axes: title={'center': 'Positive Rate'}, xlabel='Date'>
